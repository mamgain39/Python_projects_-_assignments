# %% [markdown]
# ## Context of Data
#
# 1- **Company** - UK-based and registered non-store online retail
#
# 2- **Products** for selling - Mainly all-occasion gifts
#
# 3- **Customers** - Most are wholesalers (local or international)
#
# 4- **Transactions Period** - 1st Dec 2010 - 9th Dec 2011 (One year)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import warnings
warnings.simplefilter('ignore')
# %matplotlib inline

# %%
ecom=pd.read_csv("Ecommerce-UK_Retailer.csv", encoding =('ISO-8859-2'),low_memory =False)

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
ecom.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# ## a. Boxplot – All Numeric Variables

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
sns.set(style='white')
plt.title('Quantity',fontsize=12)
sns.despine()
sns.boxplot(y='Quantity',data=ecom,width = 0.5)

plt.subplot(1,2,2)
sns.set(style='white')
plt.title('UnitPrice',fontsize=12)
sns.despine()
sns.boxplot(y='UnitPrice',data=ecom,width = 0.5)
# Out:
# <AxesSubplot:title={'center':'UnitPrice'}, ylabel='UnitPrice'>

# %% [markdown]
# ## b. Histogram – All Numeric Variables

# %%
ax.set_xlim([-10000,10000])
plt.subplot(1,2,1)
plt.hist(ecom['Quantity'], bins = 5)
plt.title('Quantity',fontsize=12)
sns.set(style='white')
sns.despine()

plt.subplot(1,2,2)
plt.hist(ecom['UnitPrice'], bins = 5)
plt.title('UnitPrice',fontsize=12)
sns.set(style='white')
sns.despine()

# %% [markdown]
# ## c. Distribution Plot – All Numeric Variables

# %%
ax.set_xlim([-10000,10000])
plt.subplot(1,2,1)
sns.distplot(ecom['UnitPrice'], kde = False)

plt.subplot(1,2,2)
sns.distplot(ecom['Quantity'], kde = False)
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %% [markdown]
# ## d. Aggregation for all numerical Columns

# %%
ecom.groupby(['Country'])[['Quantity','UnitPrice']].mean()
# Out:
#                        Quantity   UnitPrice
# Country
# Australia             66.444003    3.220612
# Austria               12.037406    4.243192
# Bahrain               13.684211    4.556316
# Belgium               11.189947    3.644335
# Brazil                11.125000    4.456250
# Canada                18.298013    6.030331
# Channel Islands       12.505277    4.932124
# Cyprus                10.155949    6.302363
# Czech Republic        19.733333    2.938333
# Denmark               21.048843    3.256941
# EIRE                  17.403245    5.911077
# European Community     8.147541    4.820492
# Finland               15.346763    5.448705
# France                12.911067    5.028864
# Germany               12.369458    3.966930
# Greece                10.657534    4.885548
# Hong Kong             16.559028   42.505208
# Iceland               13.505495    2.644011
# Israel                14.656566    3.633131
# Italy                  9.961395    4.831121
# ...

# %%
ecom.groupby(['Country'])[['Quantity','UnitPrice']].sum()
# Out:
#                       Quantity    UnitPrice
# Country
# Australia                83653     4054.750
# Austria                   4827     1701.520
# Bahrain                    260       86.570
# Belgium                  23152     7540.130
# Brazil                     356      142.600
# Canada                    2763      910.580
# Channel Islands           9479     3738.550
# Cyprus                    6317     3920.070
# Czech Republic             592       88.150
# Denmark                   8188     1266.950
# EIRE                    142637    48447.190
# European Community         497      294.050
# Finland                  10666     3786.850
# France                  110480    43031.990
# Germany                 117448    37666.000
# Greece                    1556      713.290
# Hong Kong                 4769    12241.500
# Iceland                   2458      481.210
# Israel                    4353     1079.040
# Italy                     7999     3879.390
# ...

# %%
ecom.groupby(['Country'])[['Quantity','UnitPrice']].median()
# Out:
#                       Quantity  UnitPrice
# Country
# Australia                 24.0      1.790
# Austria                    9.0      1.950
# Bahrain                    6.0      3.810
# Belgium                   10.0      1.950
# Brazil                    10.0      3.320
# Canada                    12.0      1.650
# Channel Islands           10.0      2.550
# Cyprus                     5.0      2.950
# Czech Republic            24.0      1.450
# Denmark                   12.0      1.950
# EIRE                      10.0      2.100
# European Community         6.0      3.350
# Finland                   10.0      2.080
# France                    10.0      1.790
# Germany                   10.0      1.950
# Greece                    10.0      2.100
# Hong Kong                 11.0      2.325
# Iceland                   12.0      2.015
# Israel                    11.0      1.950
# Italy                      6.0      2.550
# Japan                     36.0      1.650
# ...

# %%
ecom.groupby(['Country'])[['Quantity','UnitPrice']].min()
# Out:
#                       Quantity  UnitPrice
# Country
# Australia                 -120       0.00
# Austria                    -48       0.12
# Bahrain                    -54       1.25
# Belgium                    -12       0.12
# Brazil                       2       0.85
# Canada                       1       0.10
# Channel Islands             -2       0.19
# Cyprus                     -33       0.12
# Czech Republic             -24       0.29
# Denmark                    -25       0.21
# EIRE                      -288       0.00
# European Community          -2       0.55
# Finland                    -27       0.12
# France                    -250       0.00
# Germany                   -288       0.00
# Greece                      -1       0.14
# Hong Kong                   -1       0.21
# Iceland                      2       0.25
# Israel                     -32       0.06
# Italy                      -12       0.12
# Japan                     -624       0.21
# ...

# %%
ecom.groupby(['Country'])[['Quantity','UnitPrice']].max()
# Out:
#                       Quantity  UnitPrice
# Country
# Australia                 1152     350.00
# Austria                    288      40.00
# Bahrain                     96      12.75
# Belgium                    272      39.95
# Brazil                      24      10.95
# Canada                     504     550.94
# Channel Islands            407     293.00
# Cyprus                     288     320.69
# Czech Republic              72      40.00
# Denmark                    256      18.00
# EIRE                      1440    1917.00
# European Community          24      18.00
# Finland                    144     275.60
# France                     912    4161.06
# Germany                    600     599.50
# Greece                      48      50.00
# Hong Kong                  144    2653.95
# Iceland                    240      12.75
# Israel                     100     125.00
# Italy                      200     300.00
# Japan                     2040      45.57
# ...

# %% [markdown]
# ## e. Unique Values across all columns

# %%
len(ecom['Description'].unique())
# Out:
# 4223

# %%
len(ecom['CustomerID'].unique())
# Out:
# 4372

# %%
len(ecom['Country'].unique())
# Out:
# 38

# %%
len(ecom['InvoiceNo'].unique())
# Out:
# 25900

# %%
len(ecom['StockCode'].unique())
# Out:
# 4070

# %%
len(ecom['Quantity'].unique())
# Out:
# 722

# %%
len(ecom['InvoiceDate'].unique())
# Out:
# 23260

# %%
len(ecom['UnitPrice'].unique())
# Out:
# 1630

# %% [markdown]
# ## f. Duplicate values across all columns

# %%
ecom.duplicated(['InvoiceNo']).sum()
# Out:
# 516009

# %%
ecom.duplicated(['Country']).sum()
# Out:
# 541871

# %%
ecom.duplicated(['InvoiceDate']).sum()
# Out:
# 518649

# %%
ecom.duplicated(['Description']).sum()
# Out:
# 537686

# %%
ecom.duplicated(['CustomerID']).sum()
# Out:
# 537537

# %%
ecom.duplicated(['UnitPrice']).sum()
# Out:
# 540279

# %%
ecom.duplicated(['Quantity']).sum()
# Out:
# 541187

# %%
ecom.duplicated(['StockCode']).sum()
# Out:
# 537839

# %% [markdown]
# ## g. Correlation – Heatmap - All Numeric Variables

# %%
ecom.corr()
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
sns.heatmap(ecom.corr(),cmap='coolwarm',vmin=-1,vmax=1,annot=True,linewidth=1,linecolor='black',
            annot_kws={'fontsize':14,'fontweight':'bold'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## h. Regression Plot - All Numeric Variables

# %%
sns.regplot(x='UnitPrice',y='Quantity',data=ecom)
# Out:
# <AxesSubplot:xlabel='UnitPrice', ylabel='Quantity'>

# %% [markdown]
# ## i. Bar Plot – Every Categorical Variable vs every Numerical Variable

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Country',y='Quantity',data=ecom,ci=None)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Quantity'>

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Country',y='UnitPrice',data=ecom,ci=None)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='UnitPrice'>

# %% [markdown]
# ## j. Pair plot - All Numeric Variables

# %%
sns.pairplot(ecom,vars=['UnitPrice','Quantity'])

# %% [markdown]
# This code keeps crashing my computer and is very slow. The output is not showing even after multiple trials & errors. I have taken the two numeric varibles-"UnitPrice" and "Quantity".

# %%
# sns.pairplot(ecom,vars=['UnitPrice','Quantity'])

# %% [markdown]
# ## k. Line chart to show the trend of data - All Numeric/Date Variables

# %%
from datetime import date

# %%
ecom['InvoiceDate']=pd.to_datetime(ecom["InvoiceDate"])  #converting to datetime

# %%
ecom['Day']=ecom['InvoiceDate'].dt.date    #extracting day and creating a new column for date

# %%
plt.figure(figsize=(50,10))                       # plotting line chart for Quantity
sns.lineplot(ecom.Day,ecom.Quantity)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Quantity'>

# %%
plt.figure(figsize=(50,10))                           # Plotting line chart for Unit Price
sns.lineplot(ecom.Day,ecom.UnitPrice)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='UnitPrice'>

# %% [markdown]
# ## l. Plot the skewness - All Numeric Variables

# %%
from scipy.stats import skew

# %%
print(skew(ecom['Quantity']))                              # Plotting skewness for Quantity
plt.figure()
ax=plt.gca()
ax.set_xlim([-10000,10000])
sns.distplot(ecom['Quantity'])
plt.show()
# Out:
# -0.26407557610510857

# %%
print(skew(ecom['UnitPrice']))                                  # Plotting skewness for Unit Price
plt.figure()
ax=plt.gca()
ax.set_xlim([-10000,10000])
sns.distplot(ecom['UnitPrice'])
plt.show()
# Out:
# 186.50645547026195

# %% [markdown]
# ## 2. Check for missing values in all columns and replace them with the appropriate metric
# ## (Mean/Median/Mode)

# %%
ecom.isnull().sum()        # Checking for null values in all columns. We can see that only Description and Quantity have nulls.
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ecom['Description'].mode()[0]                # Calculating mode for Description column.
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
ecom['Description']=ecom['Description'].fillna(ecom['Description'].mode()[0])   # Replacing nulls in Description with mode.

# %%
ecom['CustomerID'].mode()[0]                 # Calculating mode for CustomerID column.
# Out:
# 17841.0

# %%
ecom['CustomerID']=ecom['CustomerID'].fillna(ecom['CustomerID'].mode()[0])      # Replacing nulls in CustomerID with mode.

# %%
ecom.isnull().sum()                      # Now we can see that there are no null values.
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# Day            0
# dtype: int64

# %% [markdown]
# ## 3. Remove duplicate rows

# %%
ecom.shape       #original shape of array
# Out:
# (541909, 9)

# %%
ecom.duplicated().sum()      #number of duplicate rows
# Out:
# 5268

# %%
ecom.loc[ecom.duplicated(keep='first'),:]                 # removing duplicated rows but keeping the first row
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country         Day
# ...

# %%
ecom.drop_duplicates(keep='first').shape                #shape of array after removing duplicate rows
# Out:
# (536641, 9)

# %% [markdown]
# ## 4. Remove rows which have negative values in Quantity column

# %%
ecom[(ecom['Quantity']<0)]                        # Checking for negative values in Quantity column
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country         Day
# ...

# %%
ecom[(ecom['Quantity']<0)].index    #specifying index of rows to be deleted
# Out:
# Int64Index([   141,    154,    235,    236,    237,    238,    239,    240,
#                241,    939,
#             ...
#             540141, 540142, 540176, 540422, 540448, 540449, 541541, 541715,
#             541716, 541717],
#            dtype='int64', length=10624)

# %%
ecom.drop(ecom[(ecom['Quantity']<0)].index)    #dropping negative value rows
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country         Day
# ...

# %% [markdown]
# ## 5. Add the columns - Month, Day and Hour for the invoice

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
ecom['Month']=ecom['InvoiceDate'].dt.month                #extract month in integer form

# %%
ecom['Day']=ecom['InvoiceDate'].dt.day                    #extract day in integer form

# %%
ecom['Hour']=ecom['InvoiceDate'].dt.hour                  #extract hour in integer form

# %%
ecom['Weekday']=ecom.InvoiceDate.dt.strftime('%a')        #extract day as name

# %%
ecom['Monthname']=ecom.InvoiceDate.dt.strftime('%b')      #extract month as name

# %%
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Day  Month  \
# ...

# %% [markdown]
# ## 6. How many orders made by the customers?

# %%
ecom['InvoiceNo'].unique()                           # identifying the unique invoice id's as each order has a unique invoice id
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
len(ecom['InvoiceNo'].unique())             #finding the number of orders by using "len" function
# Out:
# 25900

# %% [markdown]
# ## 7. TOP 5 customers with higher number of orders

# %%
# Using group by on CustomerID and count of InvoiceNo and sorting to determine the top 5 ordering customers

# %%
ecom.groupby(['CustomerID'])[['InvoiceNo']].count().sort_values(['InvoiceNo']).tail()
# Out:
#             InvoiceNo
# CustomerID
# 14606.0          2782
# 12748.0          4642
# 14096.0          5128
# 14911.0          5903
# 17841.0        143063

# %% [markdown]
# ## 8. How much money spent by the customers?

# %%
ecom['Total_Bill']=ecom['UnitPrice']*ecom['Quantity']              # Creating a new column "Total Bill"

# %%
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Day  Month  \
# ...

# %%
Total_money=round(ecom['Total_Bill'].sum(),2)             #Sum of total bill generated which is total money spent by customers

# %%
print(Total_money)
# Out:
# 9747747.93

# %% [markdown]
# ## 9. TOP 5 customers with highest money spent

# %%
# Using group by on CustomerID and sum of Total_Bill and sorting to determine the top 5 customers with highest money spent

# %%
ecom.groupby(['CustomerID'])[['Total_Bill']].sum().sort_values(['Total_Bill']).tail()
# Out:
#             Total_Bill
# CustomerID
# 12415.0      123725.45
# 14911.0      132572.62
# 17450.0      187482.17
# 18102.0      256438.49
# 14646.0      279489.02

# %% [markdown]
# ## 10. How many orders per month?

# %%
# Using group by on Monthname and count of InvoiceNo to determine number of orders per month

# %%
ecom.groupby(['Monthname'])[['InvoiceNo']].count()
# Out:
#            InvoiceNo
# Monthname
# Apr            29916
# Aug            35284
# Dec            68006
# Feb            27707
# Jan            35147
# Jul            39518
# Jun            36874
# Mar            36748
# May            37030
# Nov            84711
# Oct            60742
# Sep            50226

# %% [markdown]
# ## 11. How many orders per day?

# %%
# Using group by on Weekday and count of InvoiceNo to determine number of orders per day

# %%
ecom.groupby(['Weekday'])[['InvoiceNo']].count()
# Out:
#          InvoiceNo
# Weekday
# Fri          82193
# Mon          95111
# Sun          64375
# Thu         103857
# Tue         101808
# Wed          94565

# %% [markdown]
# ## 12. How many orders per hour?

# %%
# Using group by on Hour and count of InvoiceNo to determine number of orders per hour

# %%
ecom.groupby(['Hour'])[['InvoiceNo']].count()
# Out:
#       InvoiceNo
# Hour
# 6            41
# 7           383
# 8          8909
# 9         34332
# 10        49037
# 11        57674
# 12        78709
# 13        72259
# 14        67471
# 15        77519
# 16        54516
# 17        28509
# 18         7974
# 19         3705
# 20          871

# %% [markdown]
# ## 13. How many orders for each country?

# %%
ecom.groupby(['Country'])[['InvoiceNo']].count()
# Out:
#                       InvoiceNo
# Country
# Australia                  1259
# Austria                     401
# Bahrain                      19
# Belgium                    2069
# Brazil                       32
# Canada                      151
# Channel Islands             758
# Cyprus                      622
# Czech Republic               30
# Denmark                     389
# EIRE                       8196
# European Community           61
# Finland                     695
# France                     8557
# Germany                    9495
# Greece                      146
# Hong Kong                   288
# Iceland                     182
# Israel                      297
# Italy                       803
# Japan                       358
# Lebanon                      45
# Lithuania                    35
# Malta                       127
# Netherlands                2371
# Norway                     1086
# Poland                      341
# Portugal                   1519
# ...

# %% [markdown]
# ## 14. Orders trend across months

# %%
plt.figure(figsize=(15,20))                               
sns.lineplot(ecom.Monthname,ecom.Quantity)
#plt.yticks([])
# Out:
# <AxesSubplot:xlabel='Monthname', ylabel='Quantity'>

# %% [markdown]
# **This is a line plot between Quantity and Monthname.We can see that maximum order size is seen in February, May and August.**

# %% [markdown]
# ## 15. How much money spent by each country?

# %%
ecom.groupby(['Country'])[['Total_Bill']].sum()
# Out:
#                        Total_Bill
# Country
# Australia              137077.270
# Austria                 10154.320
# Bahrain                   548.400
# Belgium                 40910.960
# Brazil                   1143.600
# Canada                   3666.380
# Channel Islands         20086.290
# Cyprus                  12946.290
# Czech Republic            707.720
# Denmark                 18768.140
# EIRE                   263276.820
# European Community       1291.750
# Finland                 22326.740
# France                 197403.900
# Germany                221698.210
# Greece                   4710.520
# Hong Kong               10117.040
# Iceland                  4310.000
# Israel                   7907.820
# Italy                   16890.510
# Japan                   35340.620
# Lebanon                  1693.880
# Lithuania                1661.060
# Malta                    2505.470
# Netherlands            284661.540
# Norway                  35163.460
# ...
